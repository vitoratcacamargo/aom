# %% [markdown]
# # Universal Grammar Learner

# %%
INSTALL = false

if INSTALL
    using Pkg
    Pkg.activate("psyc261")
    Pkg.add(["JLD2", "Distributions", "ProgressMeter", "Parameters", 
            "Random", "Gen", "Plots", "PyCall", "Conda", "JSON3"])
end

# %%
include("../src/ug_model.jl")
using .UGmodel

# %%
using Pkg
Pkg.activate("psyc261")
using JLD2
using Distributions
using ProgressMeter
using Parameters
using Random
using Gen, Plots
using PyCall
np = pyimport("numpy")
# Out:
#   Activating project at `~/aom/notebooks/psyc261`
# PyObject <module 'numpy' from '/opt/conda/lib/python3.11/site-packages/numpy/__init__.py'>

# %% [markdown]
# ## Learning Model
