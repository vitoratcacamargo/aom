# %% [markdown]
# # Universal Grammar Generative Model

# %%
INSTALL = false

if INSTALL
    using Pkg
    Pkg.activate("psyc261")
    Pkg.add(["JLD2", "Distributions", "ProgressMeter", "Parameters", 
            "Random", "Gen", "Plots", "PyCall", "Conda", "JSON3"])
end

# %%
include("../src/ug_model.jl")
using .UGmodel

# %%
using Pkg
Pkg.activate("psyc261")
using JLD2
using Distributions
using ProgressMeter
using Parameters
using Random
using Gen, Plots
using PyCall
np = pyimport("numpy")
# Out:
#   Activating project at `~/Algorithms-of-the-Mind/aom/notebooks/psyc261`
# PyObject <module 'numpy' from '/home/psyc2610_jdp69/.local/lib/python3.11/site-packages/numpy/__init__.py'>

# %% [markdown]
# ## Generative Model

# %%
const NOUNS = UGmodel.LEXICON.nouns
const VERBS_TRANS = UGmodel.LEXICON.verbs_trans
const VERBS_INTR = UGmodel.LEXICON.verbs_intr
const ADJECTIVES = UGmodel.LEXICON.adjectives
const WH_WORD = UGmodel.LEXICON.wh_word
# Out:
# "what"

# %%
# Defining a deterministic distribution for strings so it's possible to "observe" them
struct StringDist <: Gen.Distribution{Vector{String}} end
const string_dist = StringDist()

(::StringDist)(val) = val

Gen.logpdf(::StringDist, x, val) = (x == val) ? 0. : -Inf
Gen.random(::StringDist, val) = val

# %%
# Noise constant to account for misunderstandings, slip of the tongue etc.
# Generates ungrammatical sentences
const NOISE_PROB = 0.1
# Out:
# 0.1

# %%
@gen function corpus_model(num_sentences::Int)
    # === Universal Grammar paramaters (theta) ===
    # Head direction: 1 = Verb-Object (VO), 0 = Object-Verb(OV)
    hd = @trace(bernoulli(0.5), :head_direction)

    # Subject drop: 1 = subject may be dropped, 0 = subject always present
    sd = @trace(bernoulli(0.5), :subject_drop)

    # Adjective order: 1 = Adjective-Noun (AN), 0 = Noun-Adjective (NA)
    ao = @trace(bernoulli(0.5), :adj_order)

    # Wh-fronting in question: 1 = wh-word at front, 0 = in-situ
    wh = @trace(bernoulli(0.5), :wh_fronting)
    
    sentences = Vector{Vector{String}}(undef, num_sentences)

    for i in 1:num_sentences
        # Utterance type: 1 = transitive declarative, 2 = intransitive, 3 = transitive question
        utt_type = @trace(categorical([0.4, 0.3, 0.3]), (:utt_type, i))

        # Sample lexical items
        subj_idx = @trace(categorical(fill(1/length(NOUNS), length(NOUNS))), (:subj, i))
        obj_idx = @trace(categorical(fill(1/length(NOUNS), length(NOUNS))), (:obj, i))
        adj_idx = @trace(categorical(fill(1/length(ADJECTIVES), length(ADJECTIVES))), (:adj, i))

        if utt_type == 1 || utt_type == 3
            v_idx = @trace(categorical(fill(1/length(VERBS_TRANS), length(VERBS_TRANS))), (:v_trans, i))
            verb = VERBS_TRANS[v_idx]
        else
            v_idx = @trace(categorical(fill(1/length(VERBS_INTR), length(VERBS_INTR))), (:v_intr, i))
            verb = VERBS_INTR[v_idx]
        end

        subj = NOUNS[subj_idx]
        obj = NOUNS[obj_idx]
        adj = ADJECTIVES[adj_idx]

        # Add adjective order error
        ao_slip = @trace(bernoulli(NOISE_PROB), (:ao_slip, i))
        effective_ao = ao_slip ? !ao : ao
        
        # Build NP for subject and object, respecting adjective order and taking error into account
        function make_np(noun::String, adj::String, order_rule::Bool)
            if order_rule == 1
                return [adj, noun] # Adj N
            else
                return [noun, adj] # N Adj
            end
        end

        subj_np = make_np(subj, adj, effective_ao)
        obj_np = make_np(obj, adj, effective_ao)

        # Add head direction error
        hd_slip = @trace(bernoulli(NOISE_PROB), (:hd_slip, i))
        effective_hd = hd_slip ? !hd : hd

        # Base clause word order for transitive
        vp = Vector{String}()
        if utt_type == 1 || utt_type == 3
            # Verb-Object vs. Object-Verb in the VP
            vp = (effective_hd == 1) ? vcat([verb], obj_np) : vcat(obj_np, [verb])
        else
            # Intransitive: just the verb
            vp = [verb]
        end

        # Add subject drop error
        sd_slip = @trace(bernoulli(NOISE_PROB), (:sd_slip, i))
        effective_sd = sd_slip ? !sd : sd

        # Drop subject if SD = 1
        drop_subj = (effective_sd == 1) ? @trace(bernoulli(0.5), (:drop_subj, i)) : 0

        clause = Vector{String}()

        if drop_subj == 0
            append!(clause, subj_np)
        end
        
        append!(clause, vp)

        # Handle questions
        if utt_type == 3
            wh_slip = @trace(bernoulli(NOISE_PROB), (:wh_slip, i))
            effective_wh = wh_slip ? !wh : wh
            
            if effective_wh == 1
                # wh-fronting
                clause = vcat([WH_WORD], clause)
            else
                # wh in-situ (append at the end)
                push!(clause, WH_WORD)
            end
        end

        sentences[i] = clause
    end

    return sentences
end
# Out:
# DynamicDSLFunction{Any}(Dict{Symbol, Any}(), Dict{Symbol, Any}(), Type[Int64], false, Union{Nothing, Some{Any}}[nothing], var"##corpus_model#296", Bool[0], false)

# %%
trace = simulate(corpus_model, (10,))
sentences = get_retval(trace)
theta = (
    hd = trace[:head_direction],
    sd = trace[:subject_drop],
    ao = trace[:adj_order],
    wh = trace[:wh_fronting]
)
theta
# Out:
# (hd = true, sd = false, ao = true, wh = false)

# %%
@gen function corpus_given_theta(hd::Bool, sd::Bool, ao::Bool, wh::Bool, num_sentences::Int)
    sentences = Vector{Vector{String}}(undef, num_sentences)

    for i in 1:num_sentences
        utt_type = @trace(categorical([0.4, 0.3, 0.3]), (:utt_type, i))

        subj_idx = @trace(categorical(fill(1/length(NOUNS), length(NOUNS))), (:subj, i))
        obj_idx = @trace(categorical(fill(1/length(NOUNS), length(NOUNS))), (:obj, i))
        adj_idx = @trace(categorical(fill(1/length(ADJECTIVES), length(ADJECTIVES))), (:adj, i))

        if utt_type == 1 || utt_type == 3
            v_idx = @trace(categorical(fill(1/length(VERBS_TRANS), length(VERBS_TRANS))), (:v_trans, i))
            verb = VERBS_TRANS[v_idx]
        else
            v_idx = @trace(categorical(fill(1/length(VERBS_INTR), length(VERBS_INTR))), (:v_intr, i))
            verb = VERBS_INTR[v_idx]
        end

        subj = NOUNS[subj_idx]
        obj = NOUNS[obj_idx]
        adj = ADJECTIVES[adj_idx]

        function make_np(noun::String, adj::String)
            if ao == 1
                return [adj, noun] # Adj N
            else
                return [noun, adj] # N Adj
            end
        end
        
        subj_np = make_np(subj, adj)
        obj_np = make_np(obj, adj)

        drop_subj = (sd == 1) ? @trace(bernoulli(0.5), (:drop_subj, i)) : 0

        if utt_type == 1 || utt_type == 3
            vp = (hd == 1) ? vcat([verb], obj_np) : vcat(obj_np, [verb])
        else
            vp = [verb]
        end

        clause = Vector{String}()

        if drop_subj == 0
            append!(clause, subj_np)
        end
        append!(clause, vp)

        if utt_type == 3
            if wh == 1
                clause = vcat([WH_WORD], clause)
            else
                push!(clause, WH_WORD)
            end
        end

        sentences[i] = clause
    end

    return sentences
end
# Out:
# DynamicDSLFunction{Any}(Dict{Symbol, Any}(), Dict{Symbol, Any}(), Type[Bool, Bool, Bool, Bool, Int64], false, Union{Nothing, Some{Any}}[nothing, nothing, nothing, nothing, nothing], var"##corpus_given_theta#294", Bool[0, 0, 0, 0, 0], false)

# %%
using JSON3

SAVE = true

if SAVE
    theta = (hd=false, sd=false, ao=true, wh=true)
    num_sentences = 100
    
    trace = simulate(corpus_given_theta, (theta.hd, theta.sd, theta.ao, theta.wh, num_sentences))
    corpus = get_retval(trace)
    
    open("../data/ug_language1.json", "w") do io
        JSON3.write(io, Dict("theta" => theta, "sentences" => corpus))
    end
end
# Out:
# 3356

# %% [markdown]
# ## Neural Network

# %%
# Building the fixed vocabulary
const VOCAB = unique(vcat(["PAD", WH_WORD], NOUNS, VERBS_TRANS, VERBS_INTR, ADJECTIVES))
const VOCAB_SIZE = length(VOCAB)
const WORD_TO_IDX = Dict(w => i for (i,w) in enumerate(VOCAB))
const MAX_SENT_LEN = 6
const NUM_SENTS_TRAIN = 10
const INPUT_DIM = VOCAB_SIZE * MAX_SENT_LEN * NUM_SENTS_TRAIN
# Out:
# WARNING: redefinition of constant VOCAB. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant WORD_TO_IDX. This may fail, cause incorrect answers, or produce other errors.
# 720

# %% [markdown]
# ### Encoding the sentences

# %%
# Convert sentences into a flattened one hot encoded vector
function encode_corpus(sentences::Vector{Vector{String}})
    encoded = zeros(Float64, INPUT_DIM)

    cursor = 0
    for i in 1:NUM_SENTS_TRAIN
        if i > length(sentences) break end

        sent = sentences[i]
        for j in 1:MAX_SENT_LEN
            word = j <= length(sent) ? sent[j] : "PAD"

            vocab_idx = WORD_TO_IDX[word]
            flat_idx = cursor * VOCAB_SIZE + vocab_idx

            encoded[flat_idx] = 1.0
            cursor += 1
        end
    end

    return encoded
end
# Out:
# encode_corpus (generic function with 1 method)

# %% [markdown]
# ### Creating the innate solver neural network

# %%
σ(x) = tanh.(x)
sigmoid(x) = 1.0 ./ (1.0 .+ exp.(-x))

@gen function innate_solver(input_vector::Vector{Float64})
    H = 128

    @param W1::Matrix{Float64}
    @param b1::Vector{Float64}
    @param W2::Matrix{Float64}
    @param b2::Vector{Float64}

    hidden_layer = σ(W1 * input_vector + b1)
    output = W2 * hidden_layer + b2

    probs = sigmoid(output)

    hd = @trace(bernoulli(probs[1]), :head_direction)
    sd = @trace(bernoulli(probs[2]), :subject_drop)
    ao = @trace(bernoulli(probs[3]), :adj_order)
    wh = @trace(bernoulli(probs[4]), :wh_fronting)

    return nothing
end

init_weight(out, inc) = randn(out, inc) * 0.01
init_param!(innate_solver, :W1, init_weight(128, INPUT_DIM))
init_param!(innate_solver, :b1, zeros(128))
init_param!(innate_solver, :W2, init_weight(4, 128))
init_param!(innate_solver, :b2, zeros(4))
# Out:
# 4-element Vector{Float64}:
#  0.0
#  0.0
#  0.0
#  0.0

# %% [markdown]
# ### Generating synthetic languages from the GM

# %%
function training_batch_generator()
    tr = simulate(corpus_model, (NUM_SENTS_TRAIN, ))

    sentences = get_retval(tr)
    input_vec = encode_corpus(sentences)

    constraints = Gen.choicemap()
    constraints[:head_direction] = tr[:head_direction]
    constraints[:subject_drop] = tr[:subject_drop]
    constraints[:adj_order] = tr[:adj_order]
    constraints[:wh_fronting] = tr[:wh_fronting]

    return (input_vec,), constraints
end
# Out:
# training_batch_generator (generic function with 1 method)

# %% [markdown]
# ### Training the innate solver

# %%
update = Gen.ParamUpdate(Gen.FixedStepGradientDescent(0.001), innate_solver)

NUM_EPOCHS = 200
EPOCH_SIZE = 50

TRAIN = false

if TRAIN
    scores = Gen.train!(
        innate_solver, 
        training_batch_generator, 
        update, 
        num_epoch = NUM_EPOCHS,
        epoch_size = EPOCH_SIZE,
        num_minibatch = 10,
        minibatch_size = 5,
        verbose = true
    )
end


plot(scores, label = "Loss (Neg Elbo)", xlabel = "Epochs", title = "Training innate solver")
# Out:
# epoch 1: generating 50 training examples...
# epoch 1: training using 10 minibatches of size 5...
# epoch 1: evaluating on 50 examples...
# epoch 1: est. objective value: 0.0
# epoch 2: generating 50 training examples...
# epoch 2: training using 10 minibatches of size 5...
# epoch 2: evaluating on 50 examples...
# epoch 2: est. objective value: 0.0
# epoch 3: generating 50 training examples...
# epoch 3: training using 10 minibatches of size 5...
# epoch 3: evaluating on 50 examples...
# epoch 3: est. objective value: 0.0
# epoch 4: generating 50 training examples...
# epoch 4: training using 10 minibatches of size 5...
# epoch 4: evaluating on 50 examples...
# epoch 4: est. objective value: 0.0
# epoch 5: generating 50 training examples...
# epoch 5: training using 10 minibatches of size 5...
# epoch 5: evaluating on 50 examples...
# epoch 5: est. objective value: 0.0
# epoch 6: generating 50 training examples...
# epoch 6: training using 10 minibatches of size 5...
# epoch 6: evaluating on 50 examples...
# epoch 6: est. objective value: 0.0
# epoch 7: generating 50 training examples...
# epoch 7: training using 10 minibatches of size 5...
# epoch 7: evaluating on 50 examples...
# epoch 7: est. objective value: 0.0
# epoch 8: generating 50 training examples...
# epoch 8: training using 10 minibatches of size 5...
# epoch 8: evaluating on 50 examples...
# epoch 8: est. objective value: 0.0
# epoch 9: generating 50 training examples...
# epoch 9: training using 10 minibatches of size 5...
# epoch 9: evaluating on 50 examples...
# epoch 9: est. objective value: 0.0
# epoch 10: generating 50 training examples...
# epoch 10: training using 10 minibatches of size 5...
# epoch 10: evaluating on 50 examples...
# epoch 10: est. objective value: 0.0
# epoch 11: generating 50 training examples...
# epoch 11: training using 10 minibatches of size 5...
# epoch 11: evaluating on 50 examples...
# epoch 11: est. objective value: 0.0
# epoch 12: generating 50 training examples...
# epoch 12: training using 10 minibatches of size 5...
# epoch 12: evaluating on 50 examples...
# epoch 12: est. objective value: 0.0
# epoch 13: generating 50 training examples...
# epoch 13: training using 10 minibatches of size 5...
# epoch 13: evaluating on 50 examples...
# epoch 13: est. objective value: 0.0
# epoch 14: generating 50 training examples...
# epoch 14: training using 10 minibatches of size 5...
# epoch 14: evaluating on 50 examples...
# epoch 14: est. objective value: 0.0
# epoch 15: generating 50 training examples...
# epoch 15: training using 10 minibatches of size 5...
# epoch 15: evaluating on 50 examples...
# epoch 15: est. objective value: 0.0
# epoch 16: generating 50 training examples...
# epoch 16: training using 10 minibatches of size 5...
# epoch 16: evaluating on 50 examples...
# epoch 16: est. objective value: 0.0
# epoch 17: generating 50 training examples...
# epoch 17: training using 10 minibatches of size 5...
# epoch 17: evaluating on 50 examples...
# epoch 17: est. objective value: 0.0
# epoch 18: generating 50 training examples...
# epoch 18: training using 10 minibatches of size 5...
# epoch 18: evaluating on 50 examples...
# epoch 18: est. objective value: 0.0
# epoch 19: generating 50 training examples...
# epoch 19: training using 10 minibatches of size 5...
# epoch 19: evaluating on 50 examples...
# epoch 19: est. objective value: 0.0
# epoch 20: generating 50 training examples...
# epoch 20: training using 10 minibatches of size 5...
# epoch 20: evaluating on 50 examples...
# epoch 20: est. objective value: 0.0
# epoch 21: generating 50 training examples...
# epoch 21: training using 10 minibatches of size 5...
# epoch 21: evaluating on 50 examples...
# epoch 21: est. objective value: 0.0
# epoch 22: generating 50 training examples...
# epoch 22: training using 10 minibatches of size 5...
# epoch 22: evaluating on 50 examples...
# epoch 22: est. objective value: 0.0
# epoch 23: generating 50 training examples...
# epoch 23: training using 10 minibatches of size 5...
# epoch 23: evaluating on 50 examples...
# epoch 23: est. objective value: 0.0
# epoch 24: generating 50 training examples...
# epoch 24: training using 10 minibatches of size 5...
# epoch 24: evaluating on 50 examples...
# epoch 24: est. objective value: 0.0
# epoch 25: generating 50 training examples...
# epoch 25: training using 10 minibatches of size 5...
# epoch 25: evaluating on 50 examples...
# epoch 25: est. objective value: 0.0
# epoch 26: generating 50 training examples...
# epoch 26: training using 10 minibatches of size 5...
# epoch 26: evaluating on 50 examples...
# epoch 26: est. objective value: 0.0
# epoch 27: generating 50 training examples...
# epoch 27: training using 10 minibatches of size 5...
# epoch 27: evaluating on 50 examples...
# epoch 27: est. objective value: 0.0
# epoch 28: generating 50 training examples...
# epoch 28: training using 10 minibatches of size 5...
# epoch 28: evaluating on 50 examples...
# epoch 28: est. objective value: 0.0
# epoch 29: generating 50 training examples...
# epoch 29: training using 10 minibatches of size 5...
# epoch 29: evaluating on 50 examples...
# epoch 29: est. objective value: 0.0
# epoch 30: generating 50 training examples...
# epoch 30: training using 10 minibatches of size 5...
# epoch 30: evaluating on 50 examples...
# epoch 30: est. objective value: 0.0
# epoch 31: generating 50 training examples...
# epoch 31: training using 10 minibatches of size 5...
# epoch 31: evaluating on 50 examples...
# epoch 31: est. objective value: 0.0
# epoch 32: generating 50 training examples...
# epoch 32: training using 10 minibatches of size 5...
# epoch 32: evaluating on 50 examples...
# epoch 32: est. objective value: 0.0
# epoch 33: generating 50 training examples...
# epoch 33: training using 10 minibatches of size 5...
# epoch 33: evaluating on 50 examples...
# epoch 33: est. objective value: 0.0
# epoch 34: generating 50 training examples...
# epoch 34: training using 10 minibatches of size 5...
# epoch 34: evaluating on 50 examples...
# epoch 34: est. objective value: 0.0
# epoch 35: generating 50 training examples...
# epoch 35: training using 10 minibatches of size 5...
# epoch 35: evaluating on 50 examples...
# epoch 35: est. objective value: 0.0
# epoch 36: generating 50 training examples...
# epoch 36: training using 10 minibatches of size 5...
# epoch 36: evaluating on 50 examples...
# epoch 36: est. objective value: 0.0
# epoch 37: generating 50 training examples...
# epoch 37: training using 10 minibatches of size 5...
# epoch 37: evaluating on 50 examples...
# epoch 37: est. objective value: 0.0
# epoch 38: generating 50 training examples...
# epoch 38: training using 10 minibatches of size 5...
# epoch 38: evaluating on 50 examples...
# epoch 38: est. objective value: 0.0
# epoch 39: generating 50 training examples...
# epoch 39: training using 10 minibatches of size 5...
# epoch 39: evaluating on 50 examples...
# epoch 39: est. objective value: 0.0
# epoch 40: generating 50 training examples...
# epoch 40: training using 10 minibatches of size 5...
# epoch 40: evaluating on 50 examples...
# epoch 40: est. objective value: 0.0
# epoch 41: generating 50 training examples...
# epoch 41: training using 10 minibatches of size 5...
# epoch 41: evaluating on 50 examples...
# epoch 41: est. objective value: 0.0
# epoch 42: generating 50 training examples...
# epoch 42: training using 10 minibatches of size 5...
# epoch 42: evaluating on 50 examples...
# epoch 42: est. objective value: 0.0
# epoch 43: generating 50 training examples...
# epoch 43: training using 10 minibatches of size 5...
# epoch 43: evaluating on 50 examples...
# epoch 43: est. objective value: 0.0
# epoch 44: generating 50 training examples...
# epoch 44: training using 10 minibatches of size 5...
# epoch 44: evaluating on 50 examples...
# epoch 44: est. objective value: 0.0
# epoch 45: generating 50 training examples...
# epoch 45: training using 10 minibatches of size 5...
# epoch 45: evaluating on 50 examples...
# epoch 45: est. objective value: 0.0
# epoch 46: generating 50 training examples...
# epoch 46: training using 10 minibatches of size 5...
# epoch 46: evaluating on 50 examples...
# epoch 46: est. objective value: 0.0
# epoch 47: generating 50 training examples...
# epoch 47: training using 10 minibatches of size 5...
# epoch 47: evaluating on 50 examples...
# epoch 47: est. objective value: 0.0
# epoch 48: generating 50 training examples...
# epoch 48: training using 10 minibatches of size 5...
# epoch 48: evaluating on 50 examples...
# epoch 48: est. objective value: 0.0
# epoch 49: generating 50 training examples...
# epoch 49: training using 10 minibatches of size 5...
# epoch 49: evaluating on 50 examples...
# epoch 49: est. objective value: 0.0
# epoch 50: generating 50 training examples...
# epoch 50: training using 10 minibatches of size 5...
# epoch 50: evaluating on 50 examples...
# epoch 50: est. objective value: 0.0
# epoch 51: generating 50 training examples...
# epoch 51: training using 10 minibatches of size 5...
# epoch 51: evaluating on 50 examples...
# epoch 51: est. objective value: 0.0
# epoch 52: generating 50 training examples...
# epoch 52: training using 10 minibatches of size 5...
# epoch 52: evaluating on 50 examples...
# epoch 52: est. objective value: 0.0
# epoch 53: generating 50 training examples...
# epoch 53: training using 10 minibatches of size 5...
# epoch 53: evaluating on 50 examples...
# epoch 53: est. objective value: 0.0
# epoch 54: generating 50 training examples...
# epoch 54: training using 10 minibatches of size 5...
# epoch 54: evaluating on 50 examples...
# epoch 54: est. objective value: 0.0
# epoch 55: generating 50 training examples...
# epoch 55: training using 10 minibatches of size 5...
# epoch 55: evaluating on 50 examples...
# epoch 55: est. objective value: 0.0
# epoch 56: generating 50 training examples...
# epoch 56: training using 10 minibatches of size 5...
# epoch 56: evaluating on 50 examples...
# epoch 56: est. objective value: 0.0
# epoch 57: generating 50 training examples...
# epoch 57: training using 10 minibatches of size 5...
# epoch 57: evaluating on 50 examples...
# epoch 57: est. objective value: 0.0
# epoch 58: generating 50 training examples...
# epoch 58: training using 10 minibatches of size 5...
# epoch 58: evaluating on 50 examples...
# epoch 58: est. objective value: 0.0
# epoch 59: generating 50 training examples...
# epoch 59: training using 10 minibatches of size 5...
# epoch 59: evaluating on 50 examples...
# epoch 59: est. objective value: 0.0
# epoch 60: generating 50 training examples...
# epoch 60: training using 10 minibatches of size 5...
# epoch 60: evaluating on 50 examples...
# epoch 60: est. objective value: 0.0
# epoch 61: generating 50 training examples...
# epoch 61: training using 10 minibatches of size 5...
# epoch 61: evaluating on 50 examples...
# epoch 61: est. objective value: 0.0
# epoch 62: generating 50 training examples...
# epoch 62: training using 10 minibatches of size 5...
# epoch 62: evaluating on 50 examples...
# epoch 62: est. objective value: 0.0
# epoch 63: generating 50 training examples...
# epoch 63: training using 10 minibatches of size 5...
# epoch 63: evaluating on 50 examples...
# epoch 63: est. objective value: 0.0
# epoch 64: generating 50 training examples...
# epoch 64: training using 10 minibatches of size 5...
# epoch 64: evaluating on 50 examples...
# epoch 64: est. objective value: 0.0
# epoch 65: generating 50 training examples...
# epoch 65: training using 10 minibatches of size 5...
# epoch 65: evaluating on 50 examples...
# epoch 65: est. objective value: 0.0
# epoch 66: generating 50 training examples...
# epoch 66: training using 10 minibatches of size 5...
# epoch 66: evaluating on 50 examples...
# epoch 66: est. objective value: 0.0
# epoch 67: generating 50 training examples...
# epoch 67: training using 10 minibatches of size 5...
# epoch 67: evaluating on 50 examples...
# epoch 67: est. objective value: 0.0
# epoch 68: generating 50 training examples...
# epoch 68: training using 10 minibatches of size 5...
# epoch 68: evaluating on 50 examples...
# epoch 68: est. objective value: 0.0
# epoch 69: generating 50 training examples...
# epoch 69: training using 10 minibatches of size 5...
# epoch 69: evaluating on 50 examples...
# epoch 69: est. objective value: 0.0
# epoch 70: generating 50 training examples...
# epoch 70: training using 10 minibatches of size 5...
# epoch 70: evaluating on 50 examples...
# epoch 70: est. objective value: 0.0
# epoch 71: generating 50 training examples...
# epoch 71: training using 10 minibatches of size 5...
# epoch 71: evaluating on 50 examples...
# epoch 71: est. objective value: 0.0
# epoch 72: generating 50 training examples...
# epoch 72: training using 10 minibatches of size 5...
# epoch 72: evaluating on 50 examples...
# epoch 72: est. objective value: 0.0
# epoch 73: generating 50 training examples...
# epoch 73: training using 10 minibatches of size 5...
# epoch 73: evaluating on 50 examples...
# epoch 73: est. objective value: 0.0
# epoch 74: generating 50 training examples...
# epoch 74: training using 10 minibatches of size 5...
# epoch 74: evaluating on 50 examples...
# epoch 74: est. objective value: 0.0
# epoch 75: generating 50 training examples...
# epoch 75: training using 10 minibatches of size 5...
# epoch 75: evaluating on 50 examples...
# epoch 75: est. objective value: 0.0
# epoch 76: generating 50 training examples...
# epoch 76: training using 10 minibatches of size 5...
# epoch 76: evaluating on 50 examples...
# epoch 76: est. objective value: 0.0
# epoch 77: generating 50 training examples...
# epoch 77: training using 10 minibatches of size 5...
# epoch 77: evaluating on 50 examples...
# epoch 77: est. objective value: 0.0
# epoch 78: generating 50 training examples...
# epoch 78: training using 10 minibatches of size 5...
# epoch 78: evaluating on 50 examples...
# epoch 78: est. objective value: 0.0
# epoch 79: generating 50 training examples...
# epoch 79: training using 10 minibatches of size 5...
# epoch 79: evaluating on 50 examples...
# epoch 79: est. objective value: 0.0
# epoch 80: generating 50 training examples...
# epoch 80: training using 10 minibatches of size 5...
# epoch 80: evaluating on 50 examples...
# epoch 80: est. objective value: 0.0
# epoch 81: generating 50 training examples...
# epoch 81: training using 10 minibatches of size 5...
# epoch 81: evaluating on 50 examples...
# epoch 81: est. objective value: 0.0
# epoch 82: generating 50 training examples...
# epoch 82: training using 10 minibatches of size 5...
# epoch 82: evaluating on 50 examples...
# epoch 82: est. objective value: 0.0
# epoch 83: generating 50 training examples...
# epoch 83: training using 10 minibatches of size 5...
# epoch 83: evaluating on 50 examples...
# epoch 83: est. objective value: 0.0
# epoch 84: generating 50 training examples...
# epoch 84: training using 10 minibatches of size 5...
# epoch 84: evaluating on 50 examples...
# epoch 84: est. objective value: 0.0
# epoch 85: generating 50 training examples...
# epoch 85: training using 10 minibatches of size 5...
# epoch 85: evaluating on 50 examples...
# epoch 85: est. objective value: 0.0
# epoch 86: generating 50 training examples...
# epoch 86: training using 10 minibatches of size 5...
# epoch 86: evaluating on 50 examples...
# epoch 86: est. objective value: 0.0
# epoch 87: generating 50 training examples...
# epoch 87: training using 10 minibatches of size 5...
# epoch 87: evaluating on 50 examples...
# epoch 87: est. objective value: 0.0
# epoch 88: generating 50 training examples...
# epoch 88: training using 10 minibatches of size 5...
# epoch 88: evaluating on 50 examples...
# epoch 88: est. objective value: 0.0
# epoch 89: generating 50 training examples...
# epoch 89: training using 10 minibatches of size 5...
# epoch 89: evaluating on 50 examples...
# epoch 89: est. objective value: 0.0
# epoch 90: generating 50 training examples...
# epoch 90: training using 10 minibatches of size 5...
# epoch 90: evaluating on 50 examples...
# epoch 90: est. objective value: 0.0
# epoch 91: generating 50 training examples...
# epoch 91: training using 10 minibatches of size 5...
# epoch 91: evaluating on 50 examples...
# epoch 91: est. objective value: 0.0
# epoch 92: generating 50 training examples...
# epoch 92: training using 10 minibatches of size 5...
# epoch 92: evaluating on 50 examples...
# epoch 92: est. objective value: 0.0
# epoch 93: generating 50 training examples...
# epoch 93: training using 10 minibatches of size 5...
# epoch 93: evaluating on 50 examples...
# epoch 93: est. objective value: 0.0
# epoch 94: generating 50 training examples...
# epoch 94: training using 10 minibatches of size 5...
# epoch 94: evaluating on 50 examples...
# epoch 94: est. objective value: 0.0
# epoch 95: generating 50 training examples...
# epoch 95: training using 10 minibatches of size 5...
# epoch 95: evaluating on 50 examples...
# epoch 95: est. objective value: 0.0
# epoch 96: generating 50 training examples...
# epoch 96: training using 10 minibatches of size 5...
# epoch 96: evaluating on 50 examples...
# epoch 96: est. objective value: 0.0
# epoch 97: generating 50 training examples...
# epoch 97: training using 10 minibatches of size 5...
# epoch 97: evaluating on 50 examples...
# epoch 97: est. objective value: 0.0
# epoch 98: generating 50 training examples...
# epoch 98: training using 10 minibatches of size 5...
# epoch 98: evaluating on 50 examples...
# epoch 98: est. objective value: 0.0
# epoch 99: generating 50 training examples...
# epoch 99: training using 10 minibatches of size 5...
# epoch 99: evaluating on 50 examples...
# epoch 99: est. objective value: 0.0
# epoch 100: generating 50 training examples...
# epoch 100: training using 10 minibatches of size 5...
# epoch 100: evaluating on 50 examples...
# epoch 100: est. objective value: 0.0
# epoch 101: generating 50 training examples...
# epoch 101: training using 10 minibatches of size 5...
# epoch 101: evaluating on 50 examples...
# epoch 101: est. objective value: 0.0
# epoch 102: generating 50 training examples...
# epoch 102: training using 10 minibatches of size 5...
# epoch 102: evaluating on 50 examples...
# epoch 102: est. objective value: 0.0
# epoch 103: generating 50 training examples...
# epoch 103: training using 10 minibatches of size 5...
# epoch 103: evaluating on 50 examples...
# epoch 103: est. objective value: 0.0
# epoch 104: generating 50 training examples...
# epoch 104: training using 10 minibatches of size 5...
# epoch 104: evaluating on 50 examples...
# epoch 104: est. objective value: 0.0
# epoch 105: generating 50 training examples...
# epoch 105: training using 10 minibatches of size 5...
# epoch 105: evaluating on 50 examples...
# epoch 105: est. objective value: 0.0
# epoch 106: generating 50 training examples...
# epoch 106: training using 10 minibatches of size 5...
# epoch 106: evaluating on 50 examples...
# epoch 106: est. objective value: 0.0
# epoch 107: generating 50 training examples...
# epoch 107: training using 10 minibatches of size 5...
# epoch 107: evaluating on 50 examples...
# epoch 107: est. objective value: 0.0
# epoch 108: generating 50 training examples...
# epoch 108: training using 10 minibatches of size 5...
# epoch 108: evaluating on 50 examples...
# epoch 108: est. objective value: 0.0
# epoch 109: generating 50 training examples...
# epoch 109: training using 10 minibatches of size 5...
# epoch 109: evaluating on 50 examples...
# epoch 109: est. objective value: 0.0
# epoch 110: generating 50 training examples...
# epoch 110: training using 10 minibatches of size 5...
# epoch 110: evaluating on 50 examples...
# epoch 110: est. objective value: 0.0
# epoch 111: generating 50 training examples...
# epoch 111: training using 10 minibatches of size 5...
# epoch 111: evaluating on 50 examples...
# epoch 111: est. objective value: 0.0
# epoch 112: generating 50 training examples...
# epoch 112: training using 10 minibatches of size 5...
# epoch 112: evaluating on 50 examples...
# epoch 112: est. objective value: 0.0
# epoch 113: generating 50 training examples...
# epoch 113: training using 10 minibatches of size 5...
# epoch 113: evaluating on 50 examples...
# epoch 113: est. objective value: 0.0
# epoch 114: generating 50 training examples...
# epoch 114: training using 10 minibatches of size 5...
# epoch 114: evaluating on 50 examples...
# epoch 114: est. objective value: 0.0
# epoch 115: generating 50 training examples...
# epoch 115: training using 10 minibatches of size 5...
# epoch 115: evaluating on 50 examples...
# epoch 115: est. objective value: 0.0
# epoch 116: generating 50 training examples...
# epoch 116: training using 10 minibatches of size 5...
# epoch 116: evaluating on 50 examples...
# epoch 116: est. objective value: 0.0
# epoch 117: generating 50 training examples...
# epoch 117: training using 10 minibatches of size 5...
# epoch 117: evaluating on 50 examples...
# epoch 117: est. objective value: 0.0
# epoch 118: generating 50 training examples...
# epoch 118: training using 10 minibatches of size 5...
# epoch 118: evaluating on 50 examples...
# epoch 118: est. objective value: 0.0
# epoch 119: generating 50 training examples...
# epoch 119: training using 10 minibatches of size 5...
# epoch 119: evaluating on 50 examples...
# epoch 119: est. objective value: 0.0
# epoch 120: generating 50 training examples...
# epoch 120: training using 10 minibatches of size 5...
# epoch 120: evaluating on 50 examples...
# epoch 120: est. objective value: 0.0
# epoch 121: generating 50 training examples...
# epoch 121: training using 10 minibatches of size 5...
# epoch 121: evaluating on 50 examples...
# epoch 121: est. objective value: 0.0
# epoch 122: generating 50 training examples...
# epoch 122: training using 10 minibatches of size 5...
# epoch 122: evaluating on 50 examples...
# epoch 122: est. objective value: 0.0
# epoch 123: generating 50 training examples...
# epoch 123: training using 10 minibatches of size 5...
# epoch 123: evaluating on 50 examples...
# epoch 123: est. objective value: 0.0
# epoch 124: generating 50 training examples...
# epoch 124: training using 10 minibatches of size 5...
# epoch 124: evaluating on 50 examples...
# epoch 124: est. objective value: 0.0
# epoch 125: generating 50 training examples...
# epoch 125: training using 10 minibatches of size 5...
# epoch 125: evaluating on 50 examples...
# epoch 125: est. objective value: 0.0
# epoch 126: generating 50 training examples...
# epoch 126: training using 10 minibatches of size 5...
# epoch 126: evaluating on 50 examples...
# epoch 126: est. objective value: 0.0
# epoch 127: generating 50 training examples...
# epoch 127: training using 10 minibatches of size 5...
# epoch 127: evaluating on 50 examples...
# epoch 127: est. objective value: 0.0
# epoch 128: generating 50 training examples...
# epoch 128: training using 10 minibatches of size 5...
# epoch 128: evaluating on 50 examples...
# epoch 128: est. objective value: 0.0
# epoch 129: generating 50 training examples...
# epoch 129: training using 10 minibatches of size 5...
# epoch 129: evaluating on 50 examples...
# epoch 129: est. objective value: 0.0
# epoch 130: generating 50 training examples...
# epoch 130: training using 10 minibatches of size 5...
# epoch 130: evaluating on 50 examples...
# epoch 130: est. objective value: 0.0
# epoch 131: generating 50 training examples...
# epoch 131: training using 10 minibatches of size 5...
# epoch 131: evaluating on 50 examples...
# epoch 131: est. objective value: 0.0
# epoch 132: generating 50 training examples...
# epoch 132: training using 10 minibatches of size 5...
# epoch 132: evaluating on 50 examples...
# epoch 132: est. objective value: 0.0
# epoch 133: generating 50 training examples...
# epoch 133: training using 10 minibatches of size 5...
# epoch 133: evaluating on 50 examples...
# epoch 133: est. objective value: 0.0
# epoch 134: generating 50 training examples...
# epoch 134: training using 10 minibatches of size 5...
# epoch 134: evaluating on 50 examples...
# epoch 134: est. objective value: 0.0
# epoch 135: generating 50 training examples...
# epoch 135: training using 10 minibatches of size 5...
# epoch 135: evaluating on 50 examples...
# epoch 135: est. objective value: 0.0
# epoch 136: generating 50 training examples...
# epoch 136: training using 10 minibatches of size 5...
# epoch 136: evaluating on 50 examples...
# epoch 136: est. objective value: 0.0
# epoch 137: generating 50 training examples...
# epoch 137: training using 10 minibatches of size 5...
# epoch 137: evaluating on 50 examples...
# epoch 137: est. objective value: 0.0
# epoch 138: generating 50 training examples...
# epoch 138: training using 10 minibatches of size 5...
# epoch 138: evaluating on 50 examples...
# epoch 138: est. objective value: 0.0
# epoch 139: generating 50 training examples...
# epoch 139: training using 10 minibatches of size 5...
# epoch 139: evaluating on 50 examples...
# epoch 139: est. objective value: 0.0
# epoch 140: generating 50 training examples...
# epoch 140: training using 10 minibatches of size 5...
# epoch 140: evaluating on 50 examples...
# epoch 140: est. objective value: 0.0
# epoch 141: generating 50 training examples...
# epoch 141: training using 10 minibatches of size 5...
# epoch 141: evaluating on 50 examples...
# epoch 141: est. objective value: 0.0
# epoch 142: generating 50 training examples...
# epoch 142: training using 10 minibatches of size 5...
# epoch 142: evaluating on 50 examples...
# epoch 142: est. objective value: 0.0
# epoch 143: generating 50 training examples...
# epoch 143: training using 10 minibatches of size 5...
# epoch 143: evaluating on 50 examples...
# epoch 143: est. objective value: 0.0
# epoch 144: generating 50 training examples...
# epoch 144: training using 10 minibatches of size 5...
# epoch 144: evaluating on 50 examples...
# epoch 144: est. objective value: 0.0
# epoch 145: generating 50 training examples...
# epoch 145: training using 10 minibatches of size 5...
# epoch 145: evaluating on 50 examples...
# epoch 145: est. objective value: 0.0
# epoch 146: generating 50 training examples...
# epoch 146: training using 10 minibatches of size 5...
# epoch 146: evaluating on 50 examples...
# epoch 146: est. objective value: 0.0
# epoch 147: generating 50 training examples...
# epoch 147: training using 10 minibatches of size 5...
# epoch 147: evaluating on 50 examples...
# epoch 147: est. objective value: 0.0
# epoch 148: generating 50 training examples...
# epoch 148: training using 10 minibatches of size 5...
# epoch 148: evaluating on 50 examples...
# epoch 148: est. objective value: 0.0
# epoch 149: generating 50 training examples...
# epoch 149: training using 10 minibatches of size 5...
# epoch 149: evaluating on 50 examples...
# epoch 149: est. objective value: 0.0
# epoch 150: generating 50 training examples...
# epoch 150: training using 10 minibatches of size 5...
# epoch 150: evaluating on 50 examples...
# epoch 150: est. objective value: 0.0
# epoch 151: generating 50 training examples...
# epoch 151: training using 10 minibatches of size 5...
# epoch 151: evaluating on 50 examples...
# epoch 151: est. objective value: 0.0
# epoch 152: generating 50 training examples...
# epoch 152: training using 10 minibatches of size 5...
# epoch 152: evaluating on 50 examples...
# epoch 152: est. objective value: 0.0
# epoch 153: generating 50 training examples...
# epoch 153: training using 10 minibatches of size 5...
# epoch 153: evaluating on 50 examples...
# epoch 153: est. objective value: 0.0
# epoch 154: generating 50 training examples...
# epoch 154: training using 10 minibatches of size 5...
# epoch 154: evaluating on 50 examples...
# epoch 154: est. objective value: 0.0
# epoch 155: generating 50 training examples...
# epoch 155: training using 10 minibatches of size 5...
# epoch 155: evaluating on 50 examples...
# epoch 155: est. objective value: 0.0
# epoch 156: generating 50 training examples...
# epoch 156: training using 10 minibatches of size 5...
# epoch 156: evaluating on 50 examples...
# epoch 156: est. objective value: 0.0
# epoch 157: generating 50 training examples...
# epoch 157: training using 10 minibatches of size 5...
# epoch 157: evaluating on 50 examples...
# epoch 157: est. objective value: 0.0
# epoch 158: generating 50 training examples...
# epoch 158: training using 10 minibatches of size 5...
# epoch 158: evaluating on 50 examples...
# epoch 158: est. objective value: 0.0
# epoch 159: generating 50 training examples...
# epoch 159: training using 10 minibatches of size 5...
# epoch 159: evaluating on 50 examples...
# epoch 159: est. objective value: 0.0
# epoch 160: generating 50 training examples...
# epoch 160: training using 10 minibatches of size 5...
# epoch 160: evaluating on 50 examples...
# epoch 160: est. objective value: 0.0
# epoch 161: generating 50 training examples...
# epoch 161: training using 10 minibatches of size 5...
# epoch 161: evaluating on 50 examples...
# epoch 161: est. objective value: 0.0
# epoch 162: generating 50 training examples...
# epoch 162: training using 10 minibatches of size 5...
# epoch 162: evaluating on 50 examples...
# epoch 162: est. objective value: 0.0
# epoch 163: generating 50 training examples...
# epoch 163: training using 10 minibatches of size 5...
# epoch 163: evaluating on 50 examples...
# epoch 163: est. objective value: 0.0
# epoch 164: generating 50 training examples...
# epoch 164: training using 10 minibatches of size 5...
# epoch 164: evaluating on 50 examples...
# epoch 164: est. objective value: 0.0
# epoch 165: generating 50 training examples...
# epoch 165: training using 10 minibatches of size 5...
# epoch 165: evaluating on 50 examples...
# epoch 165: est. objective value: 0.0
# epoch 166: generating 50 training examples...
# epoch 166: training using 10 minibatches of size 5...
# epoch 166: evaluating on 50 examples...
# epoch 166: est. objective value: 0.0
# epoch 167: generating 50 training examples...
# epoch 167: training using 10 minibatches of size 5...
# epoch 167: evaluating on 50 examples...
# epoch 167: est. objective value: 0.0
# epoch 168: generating 50 training examples...
# epoch 168: training using 10 minibatches of size 5...
# epoch 168: evaluating on 50 examples...
# epoch 168: est. objective value: 0.0
# epoch 169: generating 50 training examples...
# epoch 169: training using 10 minibatches of size 5...
# epoch 169: evaluating on 50 examples...
# epoch 169: est. objective value: 0.0
# epoch 170: generating 50 training examples...
# epoch 170: training using 10 minibatches of size 5...
# epoch 170: evaluating on 50 examples...
# epoch 170: est. objective value: 0.0
# epoch 171: generating 50 training examples...
# epoch 171: training using 10 minibatches of size 5...
# epoch 171: evaluating on 50 examples...
# epoch 171: est. objective value: 0.0
# epoch 172: generating 50 training examples...
# epoch 172: training using 10 minibatches of size 5...
# epoch 172: evaluating on 50 examples...
# epoch 172: est. objective value: 0.0
# epoch 173: generating 50 training examples...
# epoch 173: training using 10 minibatches of size 5...
# epoch 173: evaluating on 50 examples...
# epoch 173: est. objective value: 0.0
# epoch 174: generating 50 training examples...
# epoch 174: training using 10 minibatches of size 5...
# epoch 174: evaluating on 50 examples...
# epoch 174: est. objective value: 0.0
# epoch 175: generating 50 training examples...
# epoch 175: training using 10 minibatches of size 5...
# epoch 175: evaluating on 50 examples...
# epoch 175: est. objective value: 0.0
# epoch 176: generating 50 training examples...
# epoch 176: training using 10 minibatches of size 5...
# epoch 176: evaluating on 50 examples...
# epoch 176: est. objective value: 0.0
# epoch 177: generating 50 training examples...
# epoch 177: training using 10 minibatches of size 5...
# epoch 177: evaluating on 50 examples...
# epoch 177: est. objective value: 0.0
# epoch 178: generating 50 training examples...
# epoch 178: training using 10 minibatches of size 5...
# epoch 178: evaluating on 50 examples...
# epoch 178: est. objective value: 0.0
# epoch 179: generating 50 training examples...
# epoch 179: training using 10 minibatches of size 5...
# epoch 179: evaluating on 50 examples...
# epoch 179: est. objective value: 0.0
# epoch 180: generating 50 training examples...
# epoch 180: training using 10 minibatches of size 5...
# epoch 180: evaluating on 50 examples...
# epoch 180: est. objective value: 0.0
# epoch 181: generating 50 training examples...
# epoch 181: training using 10 minibatches of size 5...
# epoch 181: evaluating on 50 examples...
# epoch 181: est. objective value: 0.0
# epoch 182: generating 50 training examples...
# epoch 182: training using 10 minibatches of size 5...
# epoch 182: evaluating on 50 examples...
# epoch 182: est. objective value: 0.0
# epoch 183: generating 50 training examples...
# epoch 183: training using 10 minibatches of size 5...
# epoch 183: evaluating on 50 examples...
# epoch 183: est. objective value: 0.0
# epoch 184: generating 50 training examples...
# epoch 184: training using 10 minibatches of size 5...
# epoch 184: evaluating on 50 examples...
# epoch 184: est. objective value: 0.0
# epoch 185: generating 50 training examples...
# epoch 185: training using 10 minibatches of size 5...
# epoch 185: evaluating on 50 examples...
# epoch 185: est. objective value: 0.0
# epoch 186: generating 50 training examples...
# epoch 186: training using 10 minibatches of size 5...
# epoch 186: evaluating on 50 examples...
# epoch 186: est. objective value: 0.0
# epoch 187: generating 50 training examples...
# epoch 187: training using 10 minibatches of size 5...
# epoch 187: evaluating on 50 examples...
# epoch 187: est. objective value: 0.0
# epoch 188: generating 50 training examples...
# epoch 188: training using 10 minibatches of size 5...
# epoch 188: evaluating on 50 examples...
# epoch 188: est. objective value: 0.0
# epoch 189: generating 50 training examples...
# epoch 189: training using 10 minibatches of size 5...
# epoch 189: evaluating on 50 examples...
# epoch 189: est. objective value: 0.0
# epoch 190: generating 50 training examples...
# epoch 190: training using 10 minibatches of size 5...
# epoch 190: evaluating on 50 examples...
# epoch 190: est. objective value: 0.0
# epoch 191: generating 50 training examples...
# epoch 191: training using 10 minibatches of size 5...
# epoch 191: evaluating on 50 examples...
# epoch 191: est. objective value: 0.0
# epoch 192: generating 50 training examples...
# epoch 192: training using 10 minibatches of size 5...
# epoch 192: evaluating on 50 examples...
# epoch 192: est. objective value: 0.0
# epoch 193: generating 50 training examples...
# epoch 193: training using 10 minibatches of size 5...
# epoch 193: evaluating on 50 examples...
# epoch 193: est. objective value: 0.0
# epoch 194: generating 50 training examples...
# epoch 194: training using 10 minibatches of size 5...
# epoch 194: evaluating on 50 examples...
# epoch 194: est. objective value: 0.0
# epoch 195: generating 50 training examples...
# epoch 195: training using 10 minibatches of size 5...
# epoch 195: evaluating on 50 examples...
# epoch 195: est. objective value: 0.0
# epoch 196: generating 50 training examples...
# epoch 196: training using 10 minibatches of size 5...
# epoch 196: evaluating on 50 examples...
# epoch 196: est. objective value: 0.0
# epoch 197: generating 50 training examples...
# epoch 197: training using 10 minibatches of size 5...
# epoch 197: evaluating on 50 examples...
# epoch 197: est. objective value: 0.0
# epoch 198: generating 50 training examples...
# epoch 198: training using 10 minibatches of size 5...
# epoch 198: evaluating on 50 examples...
# epoch 198: est. objective value: 0.0
# epoch 199: generating 50 training examples...
# epoch 199: training using 10 minibatches of size 5...
# epoch 199: evaluating on 50 examples...
# epoch 199: est. objective value: 0.0
# epoch 200: generating 50 training examples...
# epoch 200: training using 10 minibatches of size 5...
# epoch 200: evaluating on 50 examples...
# epoch 200: est. objective value: 0.0

# %% [markdown]
# ## Comparison Innate Solver vs Naive Learner

# %%
target_theta = (hd=true, sd=false, ao=true, wh=true)

target_constraints = Gen.choicemap()
target_constraints[:head_direction] = target_theta.hd
target_constraints[:subject_drop] = target_theta.sd
target_constraints[:adj_order] = target_theta.ao
target_constraints[:wh_fronting] = target_theta.wh

tr_target, _ = generate(corpus_model, (NUM_SENTS_TRAIN,), target_constraints)
observed_sentences = get_retval(tr_target)
observed_input_vec = encode_corpus(observed_sentences)

function mh_step(tr)
    tr, _ = mh(tr, select(:head_direction))
    tr, _ = mh(tr, select(:subject_drop))
    tr, _ = mh(tr, select(:adj_order))
    tr, _ = mh(tr, select(:wh_fronting))
    return tr
end

function is_correct(tr)
    return tr[:head_direction] == target_theta.hd &&
           tr[:subject_drop] == target_theta.sd &&
           tr[:adj_order] == target_theta.ao &&
           tr[:wh_fronting] == target_theta.wh
end

naive_trace, _ = generate(corpus_model, (NUM_SENTS_TRAIN, ), Gen.choicemap())
naive_accuracy = []
for i in 1:500
    global naive_trace = mh_step(naive_trace)
    push
